# %%
import pandas as pd
import numpy as np

# %%
pip install pyxlsb
# Out:
# Requirement already satisfied: pyxlsb in d:\users\hp 15\anaconda3\lib\site-packages (1.0.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\HP 15\Desktop\project\DEEP\emissions_by_unit_and_fuel_type_c_d_aa.xlsb",
    engine="pyxlsb"
)

df.head()
# Out:
#   This file contains data collected by the Greenhouse Gas Reporting Program for 2011-2023  \
# 0  This data was reported to EPA by facilities as...
# 1  All emissions data is presented in units of me...
# 2  ** A file containing matches between each GHGR...
# 3  ** Additional information on facility location...
# 4  *** Explanation about what an "Electricity Gen...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN        NaN         NaN         NaN         NaN
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
df.head()
# Out:
#   This file contains data collected by the Greenhouse Gas Reporting Program for 2011-2023  \
# 0  This data was reported to EPA by facilities as...
# 1  All emissions data is presented in units of me...
# 2  ** A file containing matches between each GHGR...
# 3  ** Additional information on facility location...
# 4  *** Explanation about what an "Electricity Gen...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN        NaN         NaN         NaN         NaN
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
df.tail()
# Out:
#        This file contains data collected by the Greenhouse Gas Reporting Program for 2011-2023  \
# 268779                                            1003318
# 268780                                            1003318
# 268781                                            1003318
# 268782                                            1003318
# 268783                                            1003318
#
#           Unnamed: 1              Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 268779  110043796675  ZYBACH CRYOGENIC PLANT    Briscoe         TX     211111
# 268780  110043796675  ZYBACH CRYOGENIC PLANT    Briscoe         TX     211111
# 268781  110043796675  ZYBACH CRYOGENIC PLANT    Briscoe         TX     211111
# 268782  110043796675  ZYBACH CRYOGENIC PLANT    Briscoe         TX     211111
# 268783  110043796675  ZYBACH CRYOGENIC PLANT    Briscoe         TX     211111
#
#        Unnamed: 6 Unnamed: 7                         Unnamed: 8 Unnamed: 9  \
# 268779       2015        C,W  Petroleum and Natural Gas Systems  GP-Zybach
# 268780       2014        C,W  Petroleum and Natural Gas Systems  GP-Zybach
# 268781       2013        C,W  Petroleum and Natural Gas Systems  GP-Zybach
# 268782       2012        C,W  Petroleum and Natural Gas Systems  GP-Zybach
# 268783       2011        C,W  Petroleum and Natural Gas Systems  GP-Zybach
#
#                           Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 268779  OCS (Other combustion source)   Tier1/2/3          32     33757.8
# 268780  OCS (Other combustion source)   Tier1/2/3          32     32901.2
# 268781  OCS (Other combustion source)   Tier1/2/3          32     42700.7
# 268782  OCS (Other combustion source)   Tier1/2/3          32     46840.7
# 268783  OCS (Other combustion source)   Tier1/2/3          32     53482.2
#
#        Unnamed: 14 Unnamed: 15 Unnamed: 16
# 268779          16      19.072           0
# 268780        15.5      18.476           0
# 268781       20.25      24.138           0
# 268782          22      26.224           0
# 268783       25.25      30.098           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268784 entries, 0 to 268783
# Data columns (total 17 columns):
#  #   Column                                                                                   Non-Null Count   Dtype
# ---  ------                                                                                   --------------   -----
#  0   This file contains data collected by the Greenhouse Gas Reporting Program for 2011-2023  268784 non-null  object
#  1   Unnamed: 1                                                                               239089 non-null  object
#  2   Unnamed: 2                                                                               268779 non-null  object
#  3   Unnamed: 3                                                                               268779 non-null  object
#  4   Unnamed: 4                                                                               268779 non-null  object
#  5   Unnamed: 5                                                                               268763 non-null  object
#  6   Unnamed: 6                                                                               268779 non-null  object
#  7   Unnamed: 7                                                                               268779 non-null  object
#  8   Unnamed: 8                                                                               268779 non-null  object
#  9   Unnamed: 9                                                                               268779 non-null  object
#  10  Unnamed: 10                                                                              259676 non-null  object
#  11  Unnamed: 11                                                                              264851 non-null  object
#  12  Unnamed: 12                                                                              215247 non-null  object
#  13  Unnamed: 13                                                                              268779 non-null  object
#  14  Unnamed: 14                                                                              268779 non-null  object
#  15  Unnamed: 15                                                                              268779 non-null  object
#  16  Unnamed: 16                                                                              264851 non-null  object
# dtypes: object(17)
# memory usage: 34.9+ MB

# %%
df.drop(index=df.index[:5], inplace=True)

# Set the first row as header
df.columns = df.iloc[0]

# Drop the row that became the header
df = df.iloc[1:].reset_index(drop=True)

# %%
df.head()
# Out:
# 5 Facility Id        FRS Id  \
# 0     1001155  110000397516
# 1     1012147           NaN
# 2     1012147           NaN
# 3     1012147           NaN
# 4     1012147           NaN
#
# 5                                      Facility Name          City State  \
# 0  1500 South Tibbs LLC d/b/a Aurorium Indianapol...  Indianapolis    IN
# 1                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 2                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 3                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 4                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
#
# 5 Primary NAICS Code Reporting Year Industry Type (subparts)  \
# 0             325199           2023                        C
# 1             211130           2018                   C,NN,W
# 2             211130           2018                   C,NN,W
# 3             211130           2018                   C,NN,W
# 4             211130           2017                   C,NN,W
#
# 5                            Industry Type (sectors) Unit Name  \
# 0                                          Chemicals      GP-1
# 1  Natural Gas and Natural Gas Liquids Suppliers,...  CP-03.00
# 2  Natural Gas and Natural Gas Liquids Suppliers,...  CP-03.01
# 3  Natural Gas and Natural Gas Liquids Suppliers,...  CP-03.02
# 4  Natural Gas and Natural Gas Liquids Suppliers,...  CP-03.00
#
# 5                      Unit Type Unit Reporting Method  \
# 0                            NaN             Tier1/2/3
# 1  OCS (Other combustion source)             Tier1/2/3
# 2  OCS (Other combustion source)             Tier1/2/3
# 3  OCS (Other combustion source)             Tier1/2/3
# 4  OCS (Other combustion source)             Tier1/2/3
#
# 5 Unit Maximum Rated Heat Input Capacity (mmBTU/hr)  \
# 0                                              91.8
# 1                                                30
# 2                                                30
# 3                                                30
# 4                                                30
#
# 5 Unit CO2 emissions (non-biogenic)  Unit Methane (CH4) emissions   \
# 0                            64740.5                          30.5
# 1                             3304.7                           1.5
# 2                                0.2                             0
# 3                                175                             0
# 4                             9106.1                          4.25
#
# 5 Unit Nitrous Oxide (N2O) emissions   \
# 0                              36.356
# 1                               1.788
# 2                                   0
# 3                                   0
# 4                               5.066
#
# 5 Unit Biogenic CO2 emissions (metric tons)
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0

# %%
df.tail()
# Out:
# 5      Facility Id        FRS Id           Facility Name     City State  \
# 268773     1003318  110043796675  ZYBACH CRYOGENIC PLANT  Briscoe    TX
# 268774     1003318  110043796675  ZYBACH CRYOGENIC PLANT  Briscoe    TX
# 268775     1003318  110043796675  ZYBACH CRYOGENIC PLANT  Briscoe    TX
# 268776     1003318  110043796675  ZYBACH CRYOGENIC PLANT  Briscoe    TX
# 268777     1003318  110043796675  ZYBACH CRYOGENIC PLANT  Briscoe    TX
#
# 5      Primary NAICS Code Reporting Year Industry Type (subparts)  \
# 268773             211111           2015                      C,W
# 268774             211111           2014                      C,W
# 268775             211111           2013                      C,W
# 268776             211111           2012                      C,W
# 268777             211111           2011                      C,W
#
# 5                 Industry Type (sectors)  Unit Name  \
# 268773  Petroleum and Natural Gas Systems  GP-Zybach
# 268774  Petroleum and Natural Gas Systems  GP-Zybach
# 268775  Petroleum and Natural Gas Systems  GP-Zybach
# 268776  Petroleum and Natural Gas Systems  GP-Zybach
# 268777  Petroleum and Natural Gas Systems  GP-Zybach
#
# 5                           Unit Type Unit Reporting Method  \
# 268773  OCS (Other combustion source)             Tier1/2/3
# 268774  OCS (Other combustion source)             Tier1/2/3
# 268775  OCS (Other combustion source)             Tier1/2/3
# 268776  OCS (Other combustion source)             Tier1/2/3
# 268777  OCS (Other combustion source)             Tier1/2/3
#
# 5      Unit Maximum Rated Heat Input Capacity (mmBTU/hr)  \
# 268773                                                32
# 268774                                                32
# 268775                                                32
# 268776                                                32
# 268777                                                32
#
# 5      Unit CO2 emissions (non-biogenic)  Unit Methane (CH4) emissions   \
# 268773                            33757.8                            16
# 268774                            32901.2                          15.5
# 268775                            42700.7                         20.25
# 268776                            46840.7                            22
# 268777                            53482.2                         25.25
#
# 5      Unit Nitrous Oxide (N2O) emissions   \
# 268773                              19.072
# 268774                              18.476
# 268775                              24.138
# 268776                              26.224
# 268777                              30.098
#
# 5      Unit Biogenic CO2 emissions (metric tons)
# 268773                                         0
# 268774                                         0
# 268775                                         0
# 268776                                         0
# 268777                                         0

# %%
df.isnull().sum()
# Out:
# 5
# Facility Id                                              0
# FRS Id                                               29690
# Facility Name                                            0
# City                                                     0
# State                                                    0
# Primary NAICS Code                                      16
# Reporting Year                                           0
# Industry Type (subparts)                                 0
# Industry Type (sectors)                                  0
# Unit Name                                                0
# Unit Type                                             9103
# Unit Reporting Method                                 3928
# Unit Maximum Rated Heat Input Capacity (mmBTU/hr)    53532
# Unit CO2 emissions (non-biogenic)                        0
# Unit Methane (CH4) emissions                             0
# Unit Nitrous Oxide (N2O) emissions                       0
# Unit Biogenic CO2 emissions (metric tons)             3928
# dtype: int64

# %%
df.replace(['NaN', 'nan', 'None'], np.nan, inplace=True)
# Out:
# C:\Users\HP 15\AppData\Local\Temp\ipykernel_30472\3553819837.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['NaN', 'nan', 'None'], np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# 5
# Facility Id                                              0
# FRS Id                                               29690
# Facility Name                                            0
# City                                                     0
# State                                                    0
# Primary NAICS Code                                      16
# Reporting Year                                           0
# Industry Type (subparts)                                 0
# Industry Type (sectors)                                  0
# Unit Name                                                0
# Unit Type                                             9103
# Unit Reporting Method                                 3928
# Unit Maximum Rated Heat Input Capacity (mmBTU/hr)    53532
# Unit CO2 emissions (non-biogenic)                        0
# Unit Methane (CH4) emissions                             0
# Unit Nitrous Oxide (N2O) emissions                       0
# Unit Biogenic CO2 emissions (metric tons)             3928
# dtype: int64

# %%
df.to_csv("Green house.csv", index=False)

# %%
df.drop("FRS Id", axis=1, inplace=True)

# %% [markdown]
# So this column was dropped because it has null values and the column is used as a unique I dentfiyer for that we have facility ID so we have no use for this column

# %%
df.isnull().sum()
# Out:
# 5
# Facility Id                                              0
# Facility Name                                            0
# City                                                     0
# State                                                    0
# Primary NAICS Code                                      16
# Reporting Year                                           0
# Industry Type (subparts)                                 0
# Industry Type (sectors)                                  0
# Unit Name                                                0
# Unit Type                                             9103
# Unit Reporting Method                                 3928
# Unit Maximum Rated Heat Input Capacity (mmBTU/hr)    53532
# Unit CO2 emissions (non-biogenic)                        0
# Unit Methane (CH4) emissions                             0
# Unit Nitrous Oxide (N2O) emissions                       0
# Unit Biogenic CO2 emissions (metric tons)             3928
# dtype: int64

# %%
df[df["Primary NAICS Code"].isna()]
# Out:
# 5       Facility Id                  Facility Name         City State  \
# 14191       1013060     Arcosa Lightweight Indiana  Mooresville    IN
# 25848       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25849       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25850       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25851       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25852       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25853       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25854       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25855       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25856       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25857       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 25858       1000230  Blue Ridge Paper Products LLC       CANTON    NC
# 70615       1005704                DUNN PAPER INC.   PORT HURON    MI
# 172374      1000248             Otsego Paper, Inc.       OTSEGO    MI
# 172375      1000248             Otsego Paper, Inc.       OTSEGO    MI
# 172376      1000248             Otsego Paper, Inc.       OTSEGO    MI
#
# 5      Primary NAICS Code  Reporting Year Industry Type (subparts)  \
# 14191                 NaN            2022                        C
# 25848                 NaN            2022                  AA,C,TT
# 25849                 NaN            2022                  AA,C,TT
# 25850                 NaN            2022                  AA,C,TT
# 25851                 NaN            2022                  AA,C,TT
# 25852                 NaN            2022                  AA,C,TT
# 25853                 NaN            2022                  AA,C,TT
# 25854                 NaN            2022                  AA,C,TT
# 25855                 NaN            2022                  AA,C,TT
# 25856                 NaN            2022                  AA,C,TT
# 25857                 NaN            2022                  AA,C,TT
# 25858                 NaN            2022                  AA,C,TT
# 70615                 NaN            2022                        C
# 172374                NaN            2022                        C
# 172375                NaN            2022                        C
# 172376                NaN            2022                        C
#
# 5      Industry Type (sectors)                              Unit Name  \
# 14191                    Other                               GP-Kilns
# 25848    Pulp and Paper, Waste                                   GP-1
# 25849    Pulp and Paper, Waste                                   GP-2
# 25850    Pulp and Paper, Waste                         Lime Kiln No.4
# 25851    Pulp and Paper, Waste                         Lime Kiln No.5
# 25852    Pulp and Paper, Waste  PB - No. 1 Natural Gas Package Boiler
# 25853    Pulp and Paper, Waste  PB - No. 2 Natural Gas Package Boiler
# 25854    Pulp and Paper, Waste                             PB - No. 4
# 25855    Pulp and Paper, Waste                        PB - Riley Bark
# 25856    Pulp and Paper, Waste                        PB - Riley Coal
# 25857    Pulp and Paper, Waste                 Recovery Furnace No.10
# 25858    Pulp and Paper, Waste                 Recovery Furnace No.11
# 70615                    Other     GP-Boilers & Process/Space Heaters
# 172374                   Other            GP-Mill plus package boiler
# 172375                   Other                     North Turbine 0024
# 172376                   Other                     South Turbine 0025
#
# 5                                            Unit Type Unit Reporting Method  \
# 14191                    OCS (Other combustion source)             Tier1/2/3
# 25848                    OCS (Other combustion source)             Tier1/2/3
# 25849                    OCS (Other combustion source)             Tier1/2/3
# 25850                              Pulp Mill Lime Kiln                   NaN
# 25851                              Pulp Mill Lime Kiln                   NaN
# 25852                               OB (Boiler, other)             Tier1/2/3
# 25853                               OB (Boiler, other)             Tier1/2/3
# 25854        PCT (Pulverized coal, tangentially-fired)             Tier1/2/3
# 25855                                S (Stoker Boiler)             Tier1/2/3
# 25856   PCWD (Pulverized coal, wall-fired, dry bottom)             Tier1/2/3
# 25857                        Chemical Recovery Furnace                   NaN
# 25858                        Chemical Recovery Furnace                   NaN
# 70615                    OCS (Other combustion source)             Tier1/2/3
# 172374                   OCS (Other combustion source)             Tier1/2/3
# 172375             CCCT (CC (Turbine, combined cycle))             Tier1/2/3
# 172376             CCCT (CC (Turbine, combined cycle))             Tier1/2/3
#
# 5       Unit Maximum Rated Heat Input Capacity (mmBTU/hr)  \
# 14191                                              100.00
# 25848                                                1.35
# 25849                                                4.00
# 25850                                                 NaN
# 25851                                                 NaN
# 25852                                              225.00
# 25853                                              225.00
# 25854                                              535.00
# 25855                                              380.00
# 25856                                              399.00
# 25857                                                 NaN
# 25858                                                 NaN
# 70615                                               94.70
# 172374                                             242.00
# 172375                                             293.90
# 172376                                             293.90
#
# 5       Unit CO2 emissions (non-biogenic)   Unit Methane (CH4) emissions   \
# 14191                              51520.8                          24.50
# 25848                                 74.3                           0.00
# 25849                               4776.0                           2.25
# 25850                              13545.6                          15.75
# 25851                              25324.0                          28.75
# 25852                              71903.0                          34.00
# 25853                              72645.8                          34.25
# 25854                             347831.7                         907.50
# 25855                             106365.4                         420.50
# 25856                             189537.1                         467.00
# 25857                              18858.4                         233.50
# 25858                              13029.3                         253.00
# 70615                              14038.6                           6.50
# 172374                               727.6                           0.25
# 172375                             49618.2                          23.50
# 172376                             59215.8                          28.00
#
# 5       Unit Nitrous Oxide (N2O) emissions   \
# 14191                                29.204
# 25848                                 0.298
# 25849                                 2.682
# 25850                                 0.298
# 25851                                 0.298
# 25852                                40.528
# 25853                                40.826
# 25854                              1571.056
# 25855                              1335.040
# 25856                               804.898
# 25857                               610.602
# 25858                               663.348
# 70615                                 7.748
# 172374                                0.298
# 172375                               28.012
# 172376                               33.376
#
# 5       Unit Biogenic CO2 emissions (metric tons)
# 14191                                         0.0
# 25848                                         0.0
# 25849                                         0.0
# 25850                                         NaN
# 25851                                         NaN
# 25852                                         0.0
# 25853                                         0.0
# 25854                                         0.0
# 25855                                     74739.8
# 25856                                         0.0
# 25857                                         NaN
# 25858                                         NaN
# 70615                                         0.0
# 172374                                        0.0
# 172375                                        0.0
# 172376                                        0.0

# %%
df.duplicated().sum()
# Out:
# 0
